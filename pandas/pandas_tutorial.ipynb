# %% [markdown]
# # A more in-depth look at pandas

# %% [markdown]
# Besides system files and neuroimages, you are guaranteed to encounter a lot of
# spreadsheets when you're doing data-analysis. Often, you will be confronted with
# scenarios involving making large-scale changes to spreadsheets, merging them,
# filtering, and all sorts of other tasks that are hard or impossible to do my hand.
#
# A great a library called Pandas is specifically built for interacting with spreadsheets in a
# (relatively) user-friendly way!
#
# This lesson will be all about using Pandas to interact with spreadsheets.

# %%
# First, lets import pandas and a few other modules
import pandas as pd
import os
import numpy as np

# %% [markdown]
# ## Reading data

# %%
# Lets read in the results from our PyCourse survey and create a Pandas Dataframe out
# of it. The spreadsheet is in .csv format. Loading a csv in Pandas is very easy:

# load csv into a pandas dataframe
df = pd.read_csv('pd_tutorial.csv')

# %%
# this will show you your whole data frame
df
# Out:
#                        Timestamp Enter your codename here  \
# 0    2017/01/26 4:41:24 PM GMT+2                    newby
# 1    2017/01/26 5:28:15 PM GMT+2                 codename
# 2    2017/01/26 5:44:50 PM GMT+2                   CDX506
# 3    2017/01/26 6:11:12 PM GMT+2                     kees
# 4    2017/01/26 6:41:52 PM GMT+2               LuckDr@gon
# 5    2017/01/26 6:50:08 PM GMT+2                        E
# 6   2017/01/26 11:00:20 PM GMT+2                  HATEIPA
# 7    2017/01/28 1:34:59 PM GMT+2                  Snorlax
# 8   2017/01/30 12:05:44 PM GMT+2          CogNeuroStudent
# 9   2017/01/30 12:33:43 PM GMT+2                      999
# 10  2017/01/30 12:34:25 PM GMT+2               Motivated
# 11   2017/01/30 3:24:53 PM GMT+2                      NaN
# 12   2017/01/30 5:30:26 PM GMT+2                   12code
# 13   2017/01/30 5:48:52 PM GMT+2                      NaN
# 14   2017/01/30 5:48:52 PM GMT+2                 codecode
# 15   2017/01/31 9:34:36 AM GMT+2                      NaN
# 16   2017/01/31 3:09:21 PM GMT+2                    Jurre
# 17   2017/02/01 1:26:21 PM GMT+2                      NaN
# 18   2017/02/01 3:55:42 PM GMT+2                 AlzCentr
# 19   2017/02/01 4:29:41 PM GMT+2                      NaN
# 20   2017/02/01 5:39:39 PM GMT+2                      NaN
# 21  2017/02/08 11:36:58 AM GMT+2                      NaN
# 22   2017/03/17 4:12:59 PM GMT+2                      NaN
# 23   2017/03/17 4:13:39 PM GMT+2          youresteemedbul
# 24   2017/03/17 4:27:15 PM GMT+2                   Oldman
# 25   2017/03/17 4:27:37 PM GMT+2                      NaN
# 26   2017/03/17 4:29:10 PM GMT+2            Wayne Tracker
# 27   2017/03/17 4:36:05 PM GMT+2                   George
# 28   2017/03/17 4:39:59 PM GMT+2                      IEG
# 29   2017/03/17 5:14:22 PM GMT+2          Burning Giraffe
# 30   2017/03/17 5:33:18 PM GMT+2               NBASkaroff
# 31   2017/03/17 5:36:21 PM GMT+2                    Moose
# 32   2017/03/17 6:18:14 PM GMT+2                poopemoji
# 33   2017/03/17 6:20:39 PM GMT+2                    Paddy
# 34   2017/03/17 6:44:40 PM GMT+2              BananaSauce
# 35   2017/03/17 6:58:21 PM GMT+2                 Jakelton
# 36   2017/03/17 7:21:51 PM GMT+2                  BB Jek
# 37   2017/03/17 8:02:15 PM GMT+2                Steve Vai
# 38   2017/03/17 8:14:44 PM GMT+2                      NaN
# 39   2017/03/17 9:00:04 PM GMT+2                      NaN
# 40  2017/03/18 12:06:21 AM GMT+2                       KT
# 41   2017/03/18 1:22:35 AM GMT+2                 Coulter!
# 42   2017/03/18 1:48:29 AM GMT+2                  Big Dwy
# 43   2017/03/18 7:12:30 AM GMT+2                   Curtis
# 44   2017/03/18 8:13:50 AM GMT+2                    Alexa
# 45   2017/03/18 2:02:52 PM GMT+2             CoolCucumber
# 46   2017/03/18 5:08:04 PM GMT+2                    Manly
# 47   2017/03/18 5:18:12 PM GMT+2                      NaN
# 48   2017/03/18 5:42:09 PM GMT+2                      NaN
# 49   2017/03/18 7:09:54 PM GMT+2                  Batman
# 50   2017/03/18 7:18:13 PM GMT+2                      NaN
# 51  2017/03/19 12:32:08 AM GMT+2                      NaN
# 52   2017/03/19 2:22:27 AM GMT+2                        Z
#
#             What is your position?  \
# 0                          PostDoc
# 1                      PhD Student
# 2                      PhD Student
# 3                      PhD Student
# 4                      PhD Student
# 5                          PostDoc
# 6       Senior Scientist/Professor
# 7                      PhD Student
# 8                 Master's Student
# 9               Research assistant
# 10                Master's Student
# 11                     PhD Student
# 12                Master's Student
# 13                     PhD Student
# 14                     PhD Student
# 15                     PhD Student
# 16                     PhD Student
# 17                     PhD Student
# 18              Research Associate
# 19                     PhD Student
# 20              Research Associate
# 21                     PhD Student
# 22                             NaN
# 23                        dropout
# 24                        Engineer
# 25                Master's Student
# 26                             CPA
# 27                     PhD Student
# 28           Undergraduate Student
# 29                     PhD Student
# 30                          Editor
# 31               Secondary Teacher
# 32                Master's Student
# 33       Working / have Bachelor's
# 34                 Student of life
# 35                     PhD Student
# 36  Service industry professional
# 37                             NaN
# 38                     PhD Student
# 39                     PhD Student
# 40                     PhD Student
# 41           Certified welder/ GED
# 42                         Teacher
# 43                     PhD Student
# 44                     PhD Student
# 45                     PhD Student
# 46                Master's Student
# 47                             NaN
# 48                     PhD Student
# 49                    Professional
# 50                         PostDoc
# 51                         PostDoc
# 52                     PhD Student
#
#    Please select all of the following for which you have some experience  \
# 0   Using a terminal (including Linux/Unix or a Ma...
# 1   Using a terminal (including Linux/Unix or a Ma...
# 2   Using a terminal (including Linux/Unix or a Ma...
# 3   Using a terminal (including Linux/Unix or a Ma...
# 4   Using a terminal (including Linux/Unix or a Ma...
# 5   Computer programming in any language;Basic sta...
# 6   Using a terminal (including Linux/Unix or a Ma...
# 7   Using a terminal (including Linux/Unix or a Ma...
# 8         Computer programming in any language;Python
# 9   Computer programming in any language;Basic sta...
# 10  Using a terminal (including Linux/Unix or a Ma...
# 11  Using a terminal (including Linux/Unix or a Ma...
# 12  Using a terminal (including Linux/Unix or a Ma...
# 13  Processing neuroimaging data;Analyzing neuroim...
# 14  Processing neuroimaging data;Analyzing neuroim...
# 15  Using a terminal (including Linux/Unix or a Ma...
# 16                                       Graph theory
# 17  Using a terminal (including Linux/Unix or a Ma...
# 18                                                NaN
# 19  Using a terminal (including Linux/Unix or a Ma...
# 20  Using a terminal (including Linux/Unix or a Ma...
# 21                         Basic statistical analysis
# 22                                                NaN
# 23                         Basic statistical analysis
# 24  Using a terminal (including Linux/Unix or a Ma...
# 25  Using a terminal (including Linux/Unix or a Ma...
# 26                         Basic statistical analysis
# 27  Using a terminal (including Linux/Unix or a Ma...
# 28                         Basic statistical analysis
# 29  Using a terminal (including Linux/Unix or a Ma...
# 30  Using a terminal (including Linux/Unix or a Ma...
# 31                                                NaN
# 32  Using a terminal (including Linux/Unix or a Ma...
# 33  Using a terminal (including Linux/Unix or a Ma...
# 34  Analyzing neuroimaging data;Basic statistical ...
# 35  Using a terminal (including Linux/Unix or a Ma...
# 36  Using a terminal (including Linux/Unix or a Ma...
# 37                                                NaN
# 38  Using a terminal (including Linux/Unix or a Ma...
# 39  Using a terminal (including Linux/Unix or a Ma...
# 40  Computer programming in any language;Basic sta...
# 41                                                NaN
# 42  Using a terminal (including Linux/Unix or a Ma...
# 43  Using a terminal (including Linux/Unix or a Ma...
# 44  Using a terminal (including Linux/Unix or a Ma...
# 45  Using a terminal (including Linux/Unix or a Ma...
# 46  Using a terminal (including Linux/Unix or a Ma...
# 47                                                NaN
# 48  Using a terminal (including Linux/Unix or a Ma...
# 49                                                NaN
# 50  Using a terminal (including Linux/Unix or a Ma...
# 51  Using a terminal (including Linux/Unix or a Ma...
# 52  Using a terminal (including Linux/Unix or a Ma...
#
#    If you have programming experience, list languages to you are comfortable with.  \
# 0   Have been mostly using Matlab, but have taken ...
# 1                           bash, python (basic user)
# 2                                           matlab, R
# 3                                        bash, matlab
# 4                                   Python, R, Matlab
# 5                         R-programming - I tend not
# 6        I can manage in some, am comfortable in none
# 7                                                 NaN
# 8                                              Matlab
# 9                                              Delphi
# 10                                                NaN
# 11                                  Bash (very basic)
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15  Does Matlab count? I have worked a little bit ...
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                           Software used: Matlab, R
# 20                               HTML, C++, perl, CSS
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                         Python, C, C++, JavaScript
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                          R, python
# 30                                    HTML, Java, CSS
# 31                                                NaN
# 32                                     R, some python
# 33                                       Python, Java
# 34                                                NaN
# 35                                                  R
# 36                                               None
# 37                                                NaN
# 38                                             Matlab
# 39                                      Matab, Python
# 40  None. I have very basic experience with Perl a...
# 41                                                NaN
# 42                                                NaN
# 43                                             MATLAB
# 44                               Bash script, matlab
# 45                                                NaN
# 46                                                NaN
# 47                                                NaN
# 48                                             Python
# 49                                                NaN
# 50                                                NaN
# 51                                Python, JavaScript
# 52                                                NaN
#
#    If you have experience with image preprocessing software, please select which software   \
# 0                                            SPM;PMOD
# 1                                      Freesurfer;FSL
# 2                                      Freesurfer;SPM
# 3                                  Freesurfer;SPM;FSL
# 4                             Freesurfer;SPM;FSL;ANTs
# 5    I don't have experience with image preprocessing
# 6                                  Freesurfer;SPM;FSL
# 7                                  Freesurfer;SPM;FSL
# 8                                          Freesurfer
# 9    I don't have experience with image preprocessing
# 10                                                FSL
# 11                                     Freesurfer;FSL
# 12                                            SPM;FSL
# 13                                                NaN
# 14                                              Vinci
# 15                                 Freesurfer;SPM;FSL
# 16   I don't have experience with image preprocessing
# 17   I don't have experience with image preprocessing
# 18   I don't have experience with image preprocessing
# 19                                 Freesurfer;SPM;FSL
# 20                                                SPM
# 21   I don't have experience with image preprocessing
# 22                                                NaN
# 23   I don't have experience with image preprocessing
# 24   I don't have experience with image preprocessing
# 25                                                NaN
# 26                                                NaN
# 27                                           SPM;Conn
# 28                                                NaN
# 29   I don't have experience with image preprocessing
# 30   I don't have experience with image preprocessing
# 31                                                NaN
# 32   Freesurfer;FSL;ANTs;BrainSuite, AIR Tools, CIVET
# 33   I don't have experience with image preprocessing
# 34   I don't have experience with image preprocessing
# 35   I don't have experience with image preprocessing
# 36   I don't have experience with image preprocessing
# 37                                                NaN
# 38                                         Freesurfer
# 39                                                FSL
# 40                                                NaN
# 41   I don't have experience with image preprocessing
# 42   I don't have experience with image preprocessing
# 43                                               Niak
# 44                                 Freesurfer;SPM;FSL
# 45                              Freesurfer;Brainstorm
# 46                                            SPM;FSL
# 47                                                NaN
# 48                       Freesurfer;SPM;FSL;ANTs;AFNI
# 49   I don't have experience with image preprocessing
# 50                       Freesurfer;SPM;FSL;ANTs;AFNI
# 51                                Freesurfer;FSL;AFNI
# 52   I don't have experience with image preprocessing
#
#    If you have experience with image processing or analysis, which types of images?  \
# 0                                       PET;Task fMRI
# 1   Structural MRI (Qualitative);Structural MRI (Q...
# 2   Structural MRI (Qualitative);Structural MRI (Q...
# 3   Structural MRI (Qualitative);Structural MRI (Q...
# 4   PET;Structural MRI (Qualitative);Resting-state...
# 5   I don't have experience with image processing ...
# 6   PET;Structural MRI (Qualitative);Structural MR...
# 7   Structural MRI (Quantitative);Resting-state fM...
# 8   I don't have experience with image processing ...
# 9   I don't have experience with image processing ...
# 10            Structural MRI (Quantitative);Task fMRI
# 11              Structural MRI (Quantitative);DTI;ASL
# 12  Structural MRI (Qualitative);Structural MRI (Q...
# 13                                                PET
# 14                                                PET
# 15                      Structural MRI (Quantitative)
# 16                 Optical Coherence Tomography (Eye)
# 17  I don't have experience with image processing ...
# 18  I don't have experience with image processing ...
# 19  PET;Structural MRI (Qualitative);Structural MR...
# 20  PET;Structural MRI (Qualitative);Structural MR...
# 21  I don't have experience with image processing ...
# 22                                                NaN
# 23  I don't have experience with image processing ...
# 24  I don't have experience with image processing ...
# 25                                                NaN
# 26  I don't have experience with image processing ...
# 27                   Resting-state fMRI;Task fMRI;DTI
# 28                                                NaN
# 29  I don't have experience with image processing ...
# 30  I don't have experience with image processing ...
# 31                                                NaN
# 32  Structural MRI (Qualitative);Structural MRI (Q...
# 33  I don't have experience with image processing ...
# 34                       Resting-state fMRI;Task fMRI
# 35  I don't have experience with image processing ...
# 36  I don't have experience with image processing ...
# 37                                                NaN
# 38               PET;Structural MRI (Qualitative);MEG
# 39                                 Resting-state fMRI
# 40                                                PET
# 41  I don't have experience with image processing ...
# 42  I don't have experience with image processing ...
# 43   Structural MRI (Quantitative);Resting-state fMRI
# 44  Structural MRI (Qualitative);Structural MRI (Q...
# 45                                                MEG
# 46  Structural MRI (Qualitative);Structural MRI (Q...
# 47                                                NaN
# 48  PET;Structural MRI (Quantitative);Resting-stat...
# 49  I don't have experience with image processing ...
# 50  PET;Structural MRI (Qualitative);Structural MR...
# 51                                          Task fMRI
# 52  I don't have experience with image processing ...
#
#    If you have experience with statistical analysis, what are your preferred statistical softwares, engines or languages?  \
# 0                                                SPSS
# 1                                             SPSS, R
# 2                                             R, SPSS
# 3                                             R, SPSS
# 4                                              JMP, R
# 5   first R, second SPSS, very limited expercience...
# 6                               SPSS (!), SPM, Matlab
# 7                                          SPSS and R
# 8                                                 NaN
# 9                                                SPSS
# 10                                               SPSS
# 11                                              SPSS
# 12                                                NaN
# 13                                                NaN
# 14                                               spss
# 15                                               SPSS
# 16                                                NaN
# 17                                               spss
# 18                                                NaN
# 19                                              SPSS
# 20                                          SPSS, SPM
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                           R, excel
# 30                                                NaN
# 31                                                NaN
# 32                                                  R
# 33                                                NaN
# 34                                                NaN
# 35                                                  R
# 36                                                NaN
# 37                                                NaN
# 38                                                Jmp
# 39                                        SPSS, MPlus
# 40                                        SPSS, Prism
# 41                                                NaN
# 42                                               SASS
# 43                                          R, MATLAB
# 44                              R, matlab, Spss haha
# 45                                             R, JMP
# 46                                            Spss, R
# 47                                                NaN
# 48                                             Python
# 49                                                NaN
# 50                                                NaN
# 51                                                NaN
# 52                                                NaN
#
#    What operating system do you most prefer?  \
# 0                                    Windows
# 1                                     Mac OS
# 2                                 Linux/Unix
# 3                                     Mac OS
# 4                                     Mac OS
# 5                                    Windows
# 6                                     Mac OS
# 7                              no preference
# 8                                     Mac OS
# 9                                     Mac OS
# 10                                   Windows
# 11                                   Windows
# 12                                   Windows
# 13                                    Mac OS
# 14                                   Windows
# 15                                   Windows
# 16                                   Windows
# 17                                    Mac OS
# 18                                    Mac OS
# 19                                   Windows
# 20                                Linux/Unix
# 21                                   Windows
# 22                                       NaN
# 23                                   Windows
# 24                                    Mac OS
# 25                                Linux/Unix
# 26                                   Windows
# 27                                Linux/Unix
# 28                                       NaN
# 29                                    Mac OS
# 30                                    Mac OS
# 31                                    Mac OS
# 32                                    Mac OS
# 33                                Linux/Unix
# 34                                   Windows
# 35                                    Mac OS
# 36                                    Mac OS
# 37                                       NaN
# 38                                   Windows
# 39                                   Windows
# 40                                    Mac OS
# 41                                   Windows
# 42                                   Windows
# 43                                    Mac OS
# 44                                    Mac OS
# 45                                    Mac OS
# 46                                    Mac OS
# 47                                       NaN
# 48                                Linux/Unix
# 49                                    Mac OS
# 50                                Linux/Unix
# 51                                Linux/Unix
# 52                                    Mac OS
#
#    Were you born in the Netherlands?                ...                 \
# 0                                 No                ...
# 1                                 No                ...
# 2                                 No                ...
# 3                                Yes                ...
# 4                                 No                ...
# 5                                Yes                ...
# 6                                Yes                ...
# 7                                Yes                ...
# 8                                Yes                ...
# 9                                Yes                ...
# 10                               Yes                ...
# 11                               Yes                ...
# 12                                No                ...
# 13                               Yes                ...
# 14                               Yes                ...
# 15                               Yes                ...
# 16                               Yes                ...
# 17                               Yes                ...
# 18                               Yes                ...
# 19                               Yes                ...
# 20                               Yes                ...
# 21                                No                ...
# 22                                No                ...
# 23                                No                ...
# 24                                No                ...
# 25                                No                ...
# 26                                No                ...
# 27                                No                ...
# 28                                No                ...
# 29                                No                ...
# 30                                No                ...
# 31                                No                ...
# 32                                No                ...
# 33                                No                ...
# 34                                No                ...
# 35                                No                ...
# 36                                No                ...
# 37                                No                ...
# 38                                No                ...
# 39                                No                ...
# 40                                No                ...
# 41                                No                ...
# 42                                No                ...
# 43                                No                ...
# 44                                No                ...
# 45                                No                ...
# 46                                No                ...
# 47                                No                ...
# 48                                No                ...
# 49                                No                ...
# 50                                No                ...
# 51                                No                ...
# 52                                No                ...
#
#    What style of music do you most prefer? Pick another number from 1 to 100  \
# 0                        Alternative/Indie                                54
# 1                                     Rock                                87
# 2                                     Rock                                26
# 3                                      Pop                                88
# 4                                     Rock                                34
# 5                               Electronic                                70
# 6                           Classical/Jazz                                10
# 7                                      Pop                                88
# 8                                      Pop                                62
# 9                        Alternative/Indie                                54
# 10                                    Rock                                51
# 11                                     Pop                                82
# 12                       Alternative/Indie                                38
# 13                          Classical/Jazz                                54
# 14                       Alternative/Indie                                56
# 15                          Classical/Jazz                                45
# 16                                 Hip-Hop                                14
# 17                       Alternative/Indie                                99
# 18                                     Pop                                33
# 19                                    Rock                                 1
# 20                                 Hip-Hop                                66
# 21                                     Pop                                 1
# 22                       Alternative/Indie                                45
# 23                                 Hip-Hop                                27
# 24                            Country/Folk                                67
# 25                                    Rock                                 1
# 26                       Alternative/Indie                                 1
# 27                                    Rock                                48
# 28                                 Hip-Hop                                 1
# 29                       Alternative/Indie                                62
# 30                          Classical/Jazz                                67
# 31                                 Hip-Hop                                28
# 32                            Country/Folk                                45
# 33                          Classical/Jazz                                23
# 34                                    Rock                                 3
# 35                                 Hip-Hop                                43
# 36                                 Hip-Hop                                87
# 37                                    Rock                                78
# 38                                     Pop                                 2
# 39                                    Rock                                65
# 40                       Alternative/Indie                                 3
# 41                                 Hip-Hop                                48
# 42                       Alternative/Indie                                Pi
# 43                       Alternative/Indie                                76
# 44                       Alternative/Indie                                42
# 45                                     Pop                                69
# 46                       Alternative/Indie                                37
# 47                       Alternative/Indie                                12
# 48                       Alternative/Indie                                46
# 49                       Alternative/Indie                                27
# 50                       Alternative/Indie                                89
# 51                                 Hip-Hop                                30
# 52                          Classical/Jazz                                88
#
#     Do you often go to bed later than you wanted to?  \
# 0                                                 No
# 1                                                Yes
# 2                                                Yes
# 3                                                Yes
# 4                                                Yes
# 5                                                Yes
# 6                                                Yes
# 7                                                Yes
# 8                                                Yes
# 9                                                 No
# 10                                                No
# 11                                                No
# 12                                                No
# 13                                               Yes
# 14                                               Yes
# 15                                               Yes
# 16                                               Yes
# 17                                               Yes
# 18                                               Yes
# 19                                                No
# 20                                               Yes
# 21                                               Yes
# 22                                               Yes
# 23                                               Yes
# 24                                                No
# 25                                               Yes
# 26                                                No
# 27                                               Yes
# 28                                               Yes
# 29                                               Yes
# 30                                               Yes
# 31                                               Yes
# 32                                               Yes
# 33                                               Yes
# 34                                                No
# 35                                               Yes
# 36                                               Yes
# 37                                               Yes
# 38                                               Yes
# 39                                                No
# 40                                               Yes
# 41                                               Yes
# 42                                               Yes
# 43                                               Yes
# 44                                               Yes
# 45                                               Yes
# 46                                                No
# 47                                                No
# 48                                               Yes
# 49                                               Yes
# 50                                               Yes
# 51                                               Yes
# 52                                               Yes
#
#    How many hours of sleep do you typically get on week days  \
# 0                                                   7
# 1                                                   6
# 2                                                   7
# 3                                                   7
# 4                                                   7
# 5                                                   8
# 6                                                   5
# 7                                                   9
# 8                                                 7.5
# 9                                                   8
# 10                                                  8
# 11                                                  8
# 12                                                  7
# 13                                                7,5
# 14                                                  7
# 15                                                  8
# 16                                                  7
# 17                                                  6
# 18                                                  6
# 19                                                  8
# 20                                                  8
# 21                                                  7
# 22                                                6.5
# 23                                                7-8
# 24                                                  7
# 25                                                  7
# 26                                                  5
# 27                                                  7
# 28                                                  7
# 29                                                  7
# 30                                                  6
# 31                                                  7
# 32                                                  7
# 33                                                  7
# 34                                                  4
# 35                                                  6
# 36                                                8-9
# 37                                               7:30
# 38                                                5.5
# 39                                                  9
# 40                                                  8
# 41                                                  6
# 42                                                  7
# 43                                                  8
# 44                                                  7
# 45                                                  7
# 46                                                  7
# 47                                                  7
# 48                                                  7
# 49                                                  5
# 50                                                  7
# 51                                                  8
# ...
# 38                                           Negative
# 39                                        fascinating
# 40                                           Horrific
# 41                                             Fucked
# 42                                                 No
# 43                                            Asshole
# 44                                        Mysogynist
# 45                                          Dangerous
# 46                                         Hugevomit
# 47                                        Frightening
# 48                                          grotesque
# 49                                         Ridiculous
# 50                                              Nasty
# 51                                                Sad
# 52                                        ridiculous
#
#    What are the chances (in percentage from 1-100) that the Dutch National team will win a EuroCup or WorldCup championship in the next 10 years?  \
# 0                                                  15
# 1                                                  2%
# 2                                                 NaN
# 3                                                  11
# 4                                                   9
# 5                                                  60
# 6                                                   2
# 7                                                  65
# 8                                                  40
# 9                                                  20
# 10                                                12%
# 11                                                 60
# 12                                                70%
# 13                                                 56
# 14                                                 60
# 15                                                 75
# 16                                                  5
# 17                                                 50
# 18                                                 70
# 19                                                1.1
# 20                                                  0
# 21                                                30%
# 22                                                 75
# 23                                                 17
# 24                                                75%
# 25                                                 20
# 26                                                  0
# 27                                                 50
# 28                                                 50
# 29                                                NaN
# 30                                                 20
# 31                                                40%
# 32                                                 68
# 33                                                NaN
# 34                                                 20
# 35                                                 15
# 36                                                  5
# 37                                                40%
# 38                                                 12
# 39                                                100
# 40                                                 25
# 41                                               63.9
# 42                                                  3
# 43                                                 50
# 44                                                 50
# 45                                                  0
# 46                                                  3
# 47                                                 30
# 48                                                 25
# 49                                                 34
# 50                                                 75
# 51                                                 10
# 52                                                 30
#
#    What time is it right now? How good are you at sports?  \
# 0                       15:41                           4
# 1                       16:20                           3
# 2                       16:43                           1
# 3                       17:11                           1
# 4                       17:41                           3
# 5                       17:49                           1
# 6                       22:00                           4
# 7                       12:34                           4
# 8                       11:04                           4
# 9                       11:33                           4
# 10                      11:33                           4
# 11                      14:24                           4
# 12                      16:29                           4
# 13                      16:48                           4
# 14                      16:48                           4
# 15                      08:34                           3
# 16                      14:05                           4
# 17                      12:26                           3
# 18                      14:55                           4
# 19                      15:30                           3
# 20                      11:22                           5
# 21                      10:36                           3
# 22                      10:12                           4
# 23                      10:13                           4
# 24                      10:24                           3
# 25                      10:27                           1
# 26                      10:30                           5
# 27                      10:35                           3
# 28                      10:39                           5
# 29                      08:13                           2
# 30                      11:32                           2
# 31                      08:36                           5
# 32                      12:18                           2
# 33                      12:20                           5
# 34                      09:44                           2
# 35                      13:00                           3
# 36                      13:21                           3
# 37                      14:02                           3
# 38                      14:14                           2
# 39                      11:59                           3
# 40                      18:00                           3
# 41                      16:22                           3
# 42                      19:48                           3
# 43                      01:12                           2
# 44                      02:00                           3
# 45                      08:01                           4
# 46                      10:07                           3
# 47                      16:17                           1
# 48                      08:37                           5
# 49                      13:08                           2
# 50                      10:15                           3
# 51                      15:31                           3
# 52                      20:22                           3
#
#    What do you think of beards? Was this survey too long for you?
# 0                  I like them!                                No
# 1                  I like them!                               Yes
# 2                  I like them!                               Yes
# 3                         Nope.                               Yes
# 4                  I like them!                                No
# 5                         Nope.                               Yes
# 6     I'm neutral about beards.                               Yes
# 7     I'm neutral about beards.                                No
# 8                         Nope.                                No
# 9     I'm neutral about beards.                               Yes
# 10    I'm neutral about beards.                                No
# 11                 I like them!                                No
# 12                        Nope.                               Yes
# 13                        Nope.                               Yes
# 14                 I like them!                                No
# 15    I'm neutral about beards.                               Yes
# 16    I'm neutral about beards.                               Yes
# 17    I'm neutral about beards.                                No
# 18                 I like them!                                No
# 19    I'm neutral about beards.                               Yes
# 20    I'm neutral about beards.                               Yes
# 21                        Nope.                                No
# 22    I'm neutral about beards.                               Yes
# 23    I'm neutral about beards.                                No
# 24                 I like them!                                No
# 25                 I like them!                               Yes
# 26                 I like them!                                No
# 27    I'm neutral about beards.                               Yes
# 28                 I like them!                                No
# 29                 I like them!                                No
# 30                 I like them!                                No
# 31                 I like them!                                No
# 32                 I like them!                                No
# 33                 I like them!                                No
# 34                 I like them!                                No
# 35                 I like them!                                No
# 36                        Nope.                                No
# 37                 I like them!                                No
# 38    I'm neutral about beards.                                No
# 39                 I like them!                                No
# 40                 I like them!                                No
# 41                 I like them!                                No
# 42                 I like them!                               Yes
# 43                 I like them!                                No
# 44                 I like them!                               Yes
# 45                 I like them!                               Yes
# 46                 I like them!                                No
# 47                 I like them!                               Yes
# 48                 I like them!                               Yes
# 49                 I like them!                                No
# 50                 I like them!                               Yes
# 51                 I like them!                               Yes
# 52                 I like them!                                No
#
# [53 rows x 55 columns]

# %%
# Also, if you just want to see the beginning of your DataFrame, you can do this:

df.head()

# Which takes up less space. You can see the end with df.tail()
# Out:
#                      Timestamp Enter your codename here  \
# 0  2017/01/26 4:41:24 PM GMT+2                    newby
# 1  2017/01/26 5:28:15 PM GMT+2                 codename
# 2  2017/01/26 5:44:50 PM GMT+2                   CDX506
# 3  2017/01/26 6:11:12 PM GMT+2                     kees
# 4  2017/01/26 6:41:52 PM GMT+2               LuckDr@gon
#
#   What is your position?  \
# 0                PostDoc
# 1            PhD Student
# 2            PhD Student
# 3            PhD Student
# 4            PhD Student
#
#   Please select all of the following for which you have some experience  \
# 0  Using a terminal (including Linux/Unix or a Ma...
# 1  Using a terminal (including Linux/Unix or a Ma...
# 2  Using a terminal (including Linux/Unix or a Ma...
# 3  Using a terminal (including Linux/Unix or a Ma...
# 4  Using a terminal (including Linux/Unix or a Ma...
#
#   If you have programming experience, list languages to you are comfortable with.  \
# 0  Have been mostly using Matlab, but have taken ...
# 1                          bash, python (basic user)
# 2                                          matlab, R
# 3                                       bash, matlab
# 4                                  Python, R, Matlab
#
#   If you have experience with image preprocessing software, please select which software   \
# 0                                           SPM;PMOD
# 1                                     Freesurfer;FSL
# 2                                     Freesurfer;SPM
# 3                                 Freesurfer;SPM;FSL
# 4                            Freesurfer;SPM;FSL;ANTs
#
#   If you have experience with image processing or analysis, which types of images?  \
# 0                                      PET;Task fMRI
# 1  Structural MRI (Qualitative);Structural MRI (Q...
# 2  Structural MRI (Qualitative);Structural MRI (Q...
# 3  Structural MRI (Qualitative);Structural MRI (Q...
# 4  PET;Structural MRI (Qualitative);Resting-state...
#
#   If you have experience with statistical analysis, what are your preferred statistical softwares, engines or languages?  \
# 0                                               SPSS
# 1                                            SPSS, R
# 2                                            R, SPSS
# 3                                            R, SPSS
# 4                                             JMP, R
#
#   What operating system do you most prefer? Were you born in the Netherlands?  \
# 0                                   Windows                                No
# 1                                    Mac OS                                No
# 2                                Linux/Unix                                No
# 3                                    Mac OS                               Yes
# 4                                    Mac OS                                No
#
#                  ...                What style of music do you most prefer?  \
# 0                ...                                      Alternative/Indie
# 1                ...                                                   Rock
# 2                ...                                                   Rock
# 3                ...                                                    Pop
# 4                ...                                                   Rock
#
#   Pick another number from 1 to 100  \
# 0                                54
# 1                                87
# 2                                26
# 3                                88
# 4                                34
#
#    Do you often go to bed later than you wanted to?  \
# 0                                                No
# 1                                               Yes
# 2                                               Yes
# 3                                               Yes
# 4                                               Yes
#
#   How many hours of sleep do you typically get on week days  \
# 0                                                  7
# 1                                                  6
# 2                                                  7
# 3                                                  7
# 4                                                  7
#
#   Use one word to describe what you think of Donald Trump  \
# 0                                             Wrong.
# 1                                          dangerous
# 2                                         disgusting
# 3                                               haha
# 4                                            Trouble
#
#   What are the chances (in percentage from 1-100) that the Dutch National team will win a EuroCup or WorldCup championship in the next 10 years?  \
# 0                                                 15
# 1                                                 2%
# 2                                                NaN
# 3                                                 11
# 4                                                  9
#
#   What time is it right now? How good are you at sports?  \
# 0                      15:41                           4
# 1                      16:20                           3
# 2                      16:43                           1
# 3                      17:11                           1
# 4                      17:41                           3
#
#   What do you think of beards? Was this survey too long for you?
# 0                 I like them!                                No
# 1                 I like them!                               Yes
# 2                 I like them!                               Yes
# 3                        Nope.                               Yes
# 4                 I like them!                                No
#
# [5 rows x 55 columns]

# %% [markdown]
# Before I get into all the cool things we can do with out dataframe, I want to show you
# a few more points about loading Dataframes, and a few features of Dataframe objects
#
# First, this .csv import went very well -- the first row ended up as our Dataframe header as
# we wanted. However, sometimes the import doesn't go that well. Luckily, there are a few
# simple arguments that you can pass that can fix the problem. See the read_csv docstring
# to find out

# %%
pd.read_csv?

# %% [markdown]
# I'll describe some of the useful arguments here:
#
# *Sep*: if your .csv is not comma-separated at all, but delimited by some other character, you
# can set that here. For example, it it was delimited by a ;, you would just type
# `read_csv(sheet,sep=';')`
#
# *delim_whitespace*: if set to True, the Dataframe will also uses whitespace (' ') as a sep.
#
# *header*: if you have no header (no column names), you can pass `header=None`. If you're column
# names are on a different row than the first, you can type `header = x`, where x is an int
# referring to the row # of your header. If you have a multi-index (more than one level of
# column names), you can pass a list of ints indicating which rows your different headers
# are
#
# *usecols*: if you only want to use some of the columns, but not all, you can pass a list of
# ints or strs indicating the column numbers or names you want to use
#
# As you can see, there are many others, but these are the ones you might use a lot

# %% [markdown]
# ### pandas can load dataframes from many other formats as well

# %%
pd.read_excel?
#pandas.read_

# %% [markdown]
# ## Some simple functions and methods from our dataframe

# %%
# to see the number of rows
print('this spreadsheet has %s rows'%len(df))

# or the number of rows and columns
print('rows x columns = ',df.shape)
# Out:
# this spreadsheet has 53 rows
# rows x columns =  (53, 55)

# %%
# There's also a nifty function that will tell you basic statistics about every column
df.describe()
# Out:
#        How spicy do you like your food?  Pick a number from 1 to 100  \
# count                         53.000000                    53.000000
# mean                           3.339623                    42.401468
# std                            1.073158                    29.414726
# min                            1.000000                     1.000000
# 25%                            3.000000                    13.000000
# 50%                            3.000000                    44.000000
# 75%                            4.000000                    69.000000
# max                            5.000000                    99.000000
#
#        How many continents have you visited  \
# count                             53.000000
# mean                               3.000000
# std                                1.176697
# min                                1.000000
# 25%                                2.000000
# 50%                                3.000000
# 75%                                4.000000
# max                                6.000000
#
#        How good do you think you are a driving (3 is average)  \
# count                                          53.000000
# mean                                            3.396226
# std                                             1.097893
# min                                             1.000000
# 25%                                             3.000000
# 50%                                             3.000000
# 75%                                             4.000000
# max                                             5.000000
#
#        How good are you at sports?
# count                    53.000000
# mean                      3.188679
# std                       1.110381
# min                       1.000000
# 25%                       3.000000
# 50%                       3.000000
# 75%                       4.000000
# max                       5.000000

# %%
# You can also get individual statistics if you like:

df.mean()

# Note that these are the only columns returned because these are the only columns with
# all numbers in them. We'll fix that later.
# Out:
# How spicy do you like your food?                           3.339623
# Pick a number from 1 to 100                               42.401468
# How many continents have you visited                       3.000000
# How good do you think you are a driving (3 is average)     3.396226
# How good are you at sports?                                3.188679
# dtype: float64

# %%
# Dataframes have methods (functions, as you've seen above), but they also have
# attributes that can be accessed. Two of the most important are the columns and
# the index. Luckily, these are very intutive.

print('the index of df is ',df.index)
print('\n')
print('the columns of df are ',df.columns)
print('\n')

# Notice how I do not give these (parentheses) because they are not functions, they
# are attributes. Actually, they behave a lot like lists! As such, you can index and 
# slice them:
print('the index of the 14th row is ',df.index[14])
print('\n')
print('the 15th through 19th columns are ',df.columns[15:19])

# As we'll see later, you can also directly modify these attributes in the same way you would
# modify a list!
# Out:
# the index of df is  RangeIndex(start=0, stop=53, step=1)
#
#
# the columns of df are  Index(['Timestamp', 'Enter your codename here', 'What is your position?',
#        'Please select all of the following for which you have some experience',
#        'If you have programming experience, list languages to you are comfortable with.',
#        'If you have experience with image preprocessing software, please select which software ',
#        'If you have experience with image processing or analysis, which types of images?',
#        'If you have experience with statistical analysis, what are your preferred statistical softwares, engines or languages?',
#        'What operating system do you most prefer?',
#        'Were you born in the Netherlands?',
#        'List the languages you speak (conversationally)',
#        'If you had to choose one, what would be your favorite type of beer?',
#        'How spicy do you like your food?',
#        'What are your thoughts on the oxford comma?',
#        'What color is this dress? (If you're familiar with this image, what color did you think it was when you first saw it)',
#        'Name a really popular food that you don't like',
#        'Name the first five animals you can think of',
#        'When you adjust a thermostat that was set by someone else, it's usually because you want the room to be...',
#        'What color is the shirt/dress/upper-body-clothing you're wearing right now, if any?',
#        'How many romantic relationships have you been in that have lasted at least 6 months',
#        'Pick a number from 1 to 100', 'How many siblings do you have?',
#        'Do you feel sleepy a lot?', 'How many continents have you visited',
#        'How many cities have you lived in for at least six months',
#        'Do you have any food allergies or intolerances?',
#        'Have you ever practiced any non-allergy based dietary restrictions (e.g. vegetarian, gluten-free, vegan, etc)',
#        'Fill this text box with gibberish by mashing random keyboard keys',
#        'How good do you think you are a driving (3 is average)',
#        'Can you roll your tongue?',
#        'What color are the walls around you right now?',
#        'What's your favorite color?', 'What kind of cell phone do you have',
#        'Do you usually remember your dreams?',
#        'Use an emoji to describe how you feel about emojis',
#        'Do you strongly dislike the taste or texture of any of the following things?',
#        'Which of these do you regularly drink?',
#        'Do you ever eat/drink condiments straight from the bottle/can?',
#        'Type 5 random (English) words', 'Are you nervous about flying?',
#        'Which of these would you consider a sandwich?',
#        'Would you say you have a good sense of direction?', 'Can you whistle?',
#        'Assuming you stayed relatively healthy but aged normally, how old would you want to live to be?',
#        'Exactly how far in km is your commute to work?',
#        'What style of music do you most prefer?',
#        'Pick another number from 1 to 100',
#        'Do you often go to bed later than you wanted to?',
#        'How many hours of sleep do you typically get on week days',
#        'Use one word to describe what you think of Donald Trump',
#        'What are the chances (in percentage from 1-100) that the Dutch National team will win a EuroCup or WorldCup championship in the next 10 years?',
#        'What time is it right now?', 'How good are you at sports?',
#        'What do you think of beards?', 'Was this survey too long for you?'],
#       dtype='object')
#
#
# the index of the 14th row is  14
#
#
# the 15th through 19th columns are  Index(['Name a really popular food that you don't like',
#        'Name the first five animals you can think of',
#        'When you adjust a thermostat that was set by someone else, it's usually because you want the room to be...',
#        'What color is the shirt/dress/upper-body-clothing you're wearing right now, if any?'],
#       dtype='object')

# %% [markdown]
# ## Indexing, Slicing and Querying
#
# There are *many* ways to to index and slice. It can get a bit confusing because
# there is a lot of redundancy and a lot of slight differences between methods.
#
# ### You can easily print all values in a column. These approaches all have the same output

# %%
df['What do you think of beards?']

# %%
df[df.columns[-2]]

# %%
df.loc[:,'What do you think of beards?']
# Purely label-location based indexer for selection by label

# %%
df.iloc[:,-2]
#Purely integer-location based indexing for selection by position

# %% [markdown]
# ### Let's just make a mental note that a dataframe is a bunch of series together
# So any column or row could be a series

# %%
# So you can slice a column from the df and save it into its own variable that is a series
ser = df.ix[:,df.columns[-2]]
print(ser)

# %%
# These series have their own set of functions. See below:
print(ser.unique())
print('\n')
print(ser.describe())
print('\n')
print(ser.hasnans)
print('\n')
print(ser.value_counts())
print('\n')

# Actually, they have almost every function of a full dataframe!

# They can also be easily converted to lists
print(ser.tolist())

# %% [markdown]
# By the way, you can use the above methods to print multiple Series at once by putting your column labels inside of a list!

# %%
# I'll do it below, but I'll just print the beginning in order to save space

df[[df.columns[-2],df.columns[34]]].head()

# Be aware of all these different [square brackets] and how each set is doing something
# different in the line above. The outer set is used to index df, the middle set is used
# to indicate a list is being formed, and the inner sets are used to index df.columns

# %% [markdown]
# This will give the same output as above

# %%
df[['What do you think of beards?','Use an emoji to describe how you feel about emojis']].head()

# %% [markdown]
# ### Slicing rows

# %%
# Slicing rows (rather than columns) is just as simple and also include redundant functionality
# I will use two redundant commands to print every value for the 10th row

# Again, I used head() to save space

df.iloc[10]
df.ix[10].head()

# Just like with slicing columns, a slice taken along the index (a row) is also a pandas Series
# and also retains all the functions and methods of a pandas DataFrame

# %%
# Like above, you can pass slices from the index, so let's get the 8th, 9th, and 10th rows
df.ix[8:10]

# %% [markdown]
# There are also ways to get exact data points from within your Dataframe. As with
# indexing and slicing, there are several ways to go about this. I prefer the .ix
# attribute. You need only to pass it the number (or name) of the row and the name
# (or number) of the column

# %%
df.loc[5:10,'What operating system do you most prefer?']

# %%
# In much the same fashion, you can select exact slices that you want to pull out of
# the data. Here, I will print the values in the 12th-14th columns for the 2nd-4th 
# rows.

df.iloc[2:4,12:14]

# And just like the other attributes I've shown you, such slices are actually pandas
# Series and therefore come with all of the functions of a Series

# %% [markdown]
# ## Querying

# %%
# When you pass simple Truth statements to a pandas Series, it does not give you a single
# Boolean response, but rather a response for each value in the Series

homebodies = df['How many continents have you visited']
homebodies < 2

# %%
# You can use the & sign to include additional arguments in your query

driving = df['How good do you think you are a driving (3 is average)']
sports = df['How good are you at sports?']
overconfident = (sports > 4) & (driving > 4)
overconfident

# %% [markdown]
# ### You can also slice a dataframe using a query.
# Here I'll return all dataframe entries that fit the query for overconfidence

# %%
df[overconfident]

# %%
df[['Can you roll your tongue?','Do you have any food allergies or intolerances?']].head()

# %%
(df['Can you roll your tongue?'] == 'Yes') & (df['Do you have any food allergies or intolerances?'] == 'No')

# %% [markdown]
# You can also use OR statements with `|`

# %%
(df['Can you roll your tongue?'] == 'Yes') | (df['Do you have any food allergies or intolerances?'] == 'No')

# %%
# There is more you can do with querying, but for now, I'll teach you one last trick
# You can have query based on whether a certain response is within a list of values
# Here's how it works

primary_colors = ['red','blue','yellow']
df[df["What color is the shirt/dress/upper-body-clothing you're wearing right now, if any?"].isin(primary_colors)]

# %% [markdown]
# ## Modifying dataframes

# %% [markdown]
# ### let's make a copy of our old dataframe

# %%
n_df = df.copy()

# %% [markdown]
# Note that the above function will make a new dataframe that is immutable, so no information will be shared between `df` and `n_df`, meaning changing one will NOT change the other.

# %% [markdown]
# Whereas, making a "copy" like the way it will be done below will make a mutable object

# %%
newdf = df
print('here is the value at row 1, column 1 for df and newdf before modifying newdf')
print('for df: ', df.iloc[1,1])
print('for newdf: ', newdf.iloc[1,1])
print('\n')

# %% [markdown]
# So changing `newdf` will change the original `df` !

# %%
newdf.iloc[1,1] = 'changed!!'
print('here is the value at row 1, column 1 for df and newdf after modifying newdf')
print('for df: ', df.iloc[1,1])
print('for newdf: ', newdf.iloc[1,1])

# %% [markdown]
# So let's work with the immutable independent copy we made `n_df`

# %% [markdown]
# ## Modifying some value in your dataframe

# %% [markdown]
# Modifying DataFrames is fairly straightforward. As you can see, we can modify
# DataFrame values by just setting them:

# %%
print('old codename: ', n_df.loc[1,'Enter your codename here'])
n_df.loc[1,'Enter your codename here'] = 'wonder woman'
print('new codename: ', n_df.loc[1,'Enter your codename here'])

# %%
# Modifying entire rows and columns works in the same way. Let's say you wanted to update
# a subject's information (i.e. change an entire row). As long as your input dimensions
# match the dimensions of the row, it will work fine:

new_info = range(len(newdf.columns)) # creating a range the same length as the # of columns
n_df.iloc[5] = new_info # replacing the 5th row with this range of consecutive numbers
n_df.iloc[5].head() # show

# %% [markdown]
# ## Dropping columns

# %%
# let's get rid of the column called "Timestamp"
n_df.drop(labels='Timestamp',axis=1,inplace=True)

# %% [markdown]
# Note the argument `inplace=True` will make it so that the column will be permanently dropped. Otherwise the default is `inplace=False` and will just print the dataframe without that column

# %% [markdown]
# ## Dropping rows

# %% [markdown]
# ### Let's say we want to get rid of data for all people who identified as "PhD Student" as their position

# %% [markdown]
# We need to set the index to that column first

# %%
n_df.set_index('What is your position?', inplace=True)

# %%
# let's get rid of any row where "PhD Student" appears in the index
n_df.drop(labels='PhD Student', axis=0)

# but let's not make it a permanent thing because PhD students are great

# %% [markdown]
# Here's how to reset the index back to what it was

# %%
n_df.reset_index(inplace=True)

# %% [markdown]
# ## Dropping NaNs

# %%
# let's get rid of everyone who didn't provide a codename
n_df.dropna(subset=['Enter your codename here'])

# %% [markdown]
# ## Generating a new column from a current column

# %% [markdown]
# Let's say you want to create dummy variables for a new column from a column where the answers are "Yes" and "No"

# %% [markdown]
# `iterrows` is a handy method for this job as it iterates over a DataFrame rows as (index, Series) pairs.

# %%
for i,row in n_df.iterrows():
    ans = row['Can you roll your tongue?']
    if ans == 'Yes':
        n_df.loc[i, 'tongue_dummy'] = 1
    if ans == 'No':
        n_df.loc[i, 'tongue_dummy'] = 0

# %%
n_df.head()

# %% [markdown]
# ## Adding brand new rows or columns

# %%
# Adding new rows and columns is also pretty easy. Have a look:

new_col = range(len(df.index))
n_df.loc[:,'new_columns'] = new_col
n_df.head()

# %%
# You can add new rows (in this case, subjects) using the same approach. 

# set the index to codenames first
n_df.set_index('Enter your codename here', inplace=True)

new_codenames = ['twist_the_dutchie','bitterballer','Feyenoord_sux']
for cn in new_codenames:
    n_df.loc[cn] = np.full(len(n_df.columns),np.nan)
    
n_df.tail()

# %% [markdown]
# ## saving your dataframe!

# %%
n_df.to_csv('my_new_dataframe.csv',index=False)

# %% [markdown]
# Note you can save to a number of different formats. Just tab `df.to_`

# %% [markdown]
# # for more info!

# %% [markdown]
# There is *SO* much more you can do with pandas that I will not get into for right now.
# But the pandas website is a great resource. Check out for example these pages:
#
# * Cookbook: http://pandas.pydata.org/pandas-docs/stable/cookbook.html
# * Tutorials: http://pandas.pydata.org/pandas-docs/stable/tutorials.html
# * Useful statistics: http://pandas.pydata.org/pandas-docs/stable/computation.html
# * Merging spreadsheets: http://pandas.pydata.org/pandas-docs/stable/merging.html <- my personal favourite
# * Installation guide: https://pandas.pydata.org/pandas-docs/stable/install.html
# * All the documentation: https://pandas.pydata.org/pandas-docs/stable/index.html
#
# Slack me with any questions @angelatam
#
# Thanks a lot to Jake Vogel for contibuting to this notebook!
